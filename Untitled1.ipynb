# %%
# Importing all liberies we need
# 1.Importing the requests lib for requesting throw http protocol
import requests 
# 2.Importing Pandas lib for prossing the data
import pandas as pd
import numpy as np

# %%
# Importing libraries for data visualisation
import matplotlib.pyplot as plt
# This line is for plotting my charts everytime i need them, without calling plt.show() method in matplotlib 
# %matplotlib inline

# %%
# This URL is the endpoint of forbes.com API
url = 'https://www.forbes.com/forbesapi/person/rtb/0/-estWorthPrev/true.json?fields=rank,uri,personName,lastName,gender,source,industries,countryOfCitizenship,birthDate,finalWorth,estWorthPrev,imageExists,squareImage,listUri'

# %%
# We pulled the data from Forbes.com API using request
# I used the .json() method to return json object wiche is a dict
pulled_data = requests.get(url).json()
print(pulled_data)
# Out:
# {'personList': {'personsLists': [{'uri': 'elon-musk', 'rank': 1, 'listUri': 'rtb', 'finalWorth': 245099.085, 'personName': 'Elon Musk', 'source': 'Tesla, SpaceX', 'industries': ['Automotive'], 'countryOfCitizenship': 'United States', 'imageExists': True, 'gender': 'M', 'birthDate': 46915200000, 'lastName': 'Musk', 'wealthList': False, 'estWorthPrev': 243802.398278, 'familyList': False, 'squareImage': 'https://specials-images.forbesimg.com/imageserve/5f47d4de7637290765bce495/416x416.jpg?background=000000&cropX1=1699&cropX2=3845&cropY1=559&cropY2=2704', 'bioSuppress': False}, {'uri': 'bernard-arnault', 'rank': 3, 'listUri': 'rtb', 'finalWorth': 190894.988, 'personName': 'Bernard Arnault & family', 'source': 'LVMH', 'industries': ['Fashion & Retail'], 'countryOfCitizenship': 'France', 'imageExists': True, 'gender': 'M', 'birthDate': -657244800000, 'lastName': 'Arnault', 'wealthList': False, 'estWorthPrev': 194919.714671, 'familyList': False, 'squareImage': '//specials-images.forbesimg.com/imageserve/5dc05518ca425400079c659f/416x416.jpg?background=000000&cropX1=0&cropX2=4000&cropY1=1209&cropY2=5212', 'bioSuppress': False}, {'uri': 'jeff-bezos', 'rank': 2, 'listUri': 'rtb', 'finalWorth': 195904.053, 'personName': 'Jeff Bezos', 'source': 'Amazon', 'industries': ['Technology'], 'countryOfCitizenship': 'United States', 'imageExists': True, 'gender': 'M', 'birthDate': -188438400000, 'lastName': 'Bezos', 'wealthList': False, 'estWorthPrev': 194758.37888, 'familyList': False, 'squareImage': 'https://specials-images.forbesimg.com/imageserve/5bb22ae84bbe6f67d2e82e05/416x416.jpg?background=000000&cropX1=627&cropX2=1639&cropY1=129&cropY2=1142', 'bioSuppress': False}, {'uri': 'bill-gates', 'rank': 4, 'listUri': 'rtb', 'finalWorth': 136434.782, 'personName': 'Bill Gates', 'source': 'Microsoft', 'industries': ['Technology'], 'countryOfCitizenship': 'United States', 'imageExists': True, 'gender': 'M', 'birthDate': -447465600000, 'lastName': 'Gates', 'wealthList': False, 'estWorthPrev': 137480.19124, 'familyList': False, 'squareImage': 'https://specials-images.forbesimg.com/imageserve/5f4ebe0c87612dab4f12a597/416x416.jpg?background=000000&cropX1=292&cropX2=3684&cropY1=592&cropY2=3987', 'bioSuppress': False}, {'uri': 'larry-ellison', 'rank': 5, 'listUri': 'rtb', 'finalWorth': 127922.902, 'personName': 'Larry Ellison', 'source': 'software', 'industries': ['Technology'], 'countryOfCitizenship': 'United States', 'imageExists': True, 'gender': 'M', 'birthDate': -800755200000, 'lastName': 'Ellison', 'wealthList': False, 'estWorthPrev': 134949.620303, 'familyList': False, 'squareImage': '//specials-images.forbesimg.com/imageserve/5e8b62cfc095010007bffea0/416x416.jpg?background=000000&cropX1=0&cropX2=4529&cropY1=652&cropY2=5184', 'bioSuppress': False}, {'uri': 'larry-page', 'rank': 6, 'listUri': 'rtb', 'finalWorth': 121500.649, 'personName': 'Larry Page', 'source': 'Google', 'industries': ['Technology'], 'countryOfCitizenship': 'United States', 'imageExists': True, 'gender': 'M', 'birthDate': 101952000000, 'lastName': 'Page', 'wealthList': False, 'estWorthPrev': 123390.17837, 'familyList': False, 'squareImage': '//specials-images.forbesimg.com/imageserve/5c76bcaaa7ea43100043c836/416x416.jpg?background=000000&cropX1=227&cropX2=2022&cropY1=22&cropY2=1817', 'bioSuppress': False}, {'uri': 'mark-zuckerberg', 'rank': 7, 'listUri': 'rtb', 'finalWorth': 119421.209, 'personName': 'Mark Zuckerberg', 'source': 'Facebook', 'industries': ['Technology'], 'countryOfCitizenship': 'United States', 'imageExists': True, 'gender': 'M', 'birthDate': 453340800000, 'lastName': 'Zuckerberg', 'wealthList': False, 'estWorthPrev': 119811.818, 'familyList': False, 'squareImage': '//specials-images.forbesimg.com/imageserve/5c76b7d331358e35dd2773a9/416x416.jpg?background=000000&cropX1=0&cropX2=4401&cropY1=0&cropY2=4401', 'bioSuppress': False}, {'uri': 'sergey-brin', 'rank': 8, 'listUri': 'rtb', 'finalWorth': 117086.884, 'personName': 'Sergey Brin', 'source': 'Google', 'industries': [ ...

# %%
# We get our pulleded data as python dict
type(pulled_data)
# Out:
# dict

# %%
# Our pulled data is now a nested dict, so we need to access keys to get the data we need
# Let's access first key of the dict whiche is 
dictt = pulled_data['personList']
# Let's acces second key to get 
data_list = dictt['personsLists']

# %%
# Let's use Pandas to build our dataframe object
df = pd.DataFrame(data_list)
df.head(10)
# Out:
#                uri  rank listUri  finalWorth                personName  \
# 0        elon-musk     1     rtb  245099.085                 Elon Musk
# 1  bernard-arnault     3     rtb  190894.988  Bernard Arnault & family
# 2       jeff-bezos     2     rtb  195904.053                Jeff Bezos
# 3       bill-gates     4     rtb  136434.782                Bill Gates
# 4    larry-ellison     5     rtb  127922.902             Larry Ellison
# 5       larry-page     6     rtb  121500.649                Larry Page
# 6  mark-zuckerberg     7     rtb  119421.209           Mark Zuckerberg
# 7      sergey-brin     8     rtb  117086.884               Sergey Brin
# 8   warren-buffett     9     rtb  106848.201            Warren Buffett
# 9    steve-ballmer    10     rtb  102514.694             Steve Ballmer
#
#                source               industries countryOfCitizenship  \
# 0       Tesla, SpaceX             [Automotive]        United States
# 1                LVMH       [Fashion & Retail]               France
# 2              Amazon             [Technology]        United States
# 3           Microsoft             [Technology]        United States
# 4            software             [Technology]        United States
# 5              Google             [Technology]        United States
# 6            Facebook             [Technology]        United States
# 7              Google             [Technology]        United States
# 8  Berkshire Hathaway  [Finance & Investments]        United States
# 9           Microsoft             [Technology]        United States
#
#    imageExists gender     birthDate    lastName  wealthList   estWorthPrev  \
# 0         True      M  4.691520e+10        Musk       False  243802.398278
# 1         True      M -6.572448e+11     Arnault       False  194919.714671
# 2         True      M -1.884384e+11       Bezos       False  194758.378880
# 3         True      M -4.474656e+11       Gates       False  137480.191240
# 4         True      M -8.007552e+11     Ellison       False  134949.620303
# 5         True      M  1.019520e+11        Page       False  123390.178370
# 6         True      M  4.533408e+11  Zuckerberg       False  119811.818000
# 7         True      M  1.147392e+11        Brin       False  118893.997680
# 8         True      M -1.241482e+12     Buffett       False  109533.525330
# 9         True      M -4.346784e+11     Ballmer       False  102807.459900
#
#    familyList                                        squareImage  bioSuppress
# 0       False  https://specials-images.forbesimg.com/imageser...        False
# 1       False  //specials-images.forbesimg.com/imageserve/5dc...        False
# 2       False  https://specials-images.forbesimg.com/imageser...        False
# 3       False  https://specials-images.forbesimg.com/imageser...        False
# 4       False  //specials-images.forbesimg.com/imageserve/5e8...        False
# 5       False  //specials-images.forbesimg.com/imageserve/5c7...        False
# 6       False  //specials-images.forbesimg.com/imageserve/5c7...        False
# 7       False  //specials-images.forbesimg.com/imageserve/5c7...        False
# 8       False  //specials-images.forbesimg.com/imageserve/5ba...        False
# 9       False  //specials-images.forbesimg.com/imageserve/59d...        False

# %%
# Getting some infos about our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   uri                   2662 non-null   object
#  1   rank                  2662 non-null   int64
#  2   listUri               2662 non-null   object
#  3   finalWorth            2662 non-null   float64
#  4   personName            2662 non-null   object
#  5   source                2652 non-null   object
#  6   industries            2646 non-null   object
#  7   countryOfCitizenship  2662 non-null   object
#  8   imageExists           2662 non-null   bool
#  9   gender                2646 non-null   object
#  10  birthDate             2556 non-null   float64
#  11  lastName              2662 non-null   object
#  12  wealthList            2662 non-null   bool
#  13  estWorthPrev          2662 non-null   float64
#  14  familyList            2662 non-null   bool
#  15  squareImage           1989 non-null   object
#  16  bioSuppress           2662 non-null   bool
# dtypes: bool(4), float64(3), int64(1), object(9)
# memory usage: 280.9+ KB

# %%
# As u can see in birthDate column we have a problem with type of data 
df['birthDate']
# Out:
# 0       4.691520e+10
# 1      -6.572448e+11
# 2      -1.884384e+11
# 3      -4.474656e+11
# 4      -8.007552e+11
#             ...
# 2657   -1.262304e+12
# 2658    1.458432e+11
# 2659    2.209248e+11
# 2660   -9.603360e+11
# 2661    3.786912e+11
# Name: birthDate, Length: 2662, dtype: float64

# %%
# It's time to make our column change from float64 to datetime object to make it more sense
# Notice that set unit to milisecond to get date from 
df['birthDate'] = pd.to_datetime(df['birthDate'], unit='ms')
df['birthDate']
# Out:
# 0      1971-06-28
# 1      1949-03-05
# 2      1964-01-12
# 3      1955-10-28
# 4      1944-08-17
#           ...
# 2657   1930-01-01
# 2658   1974-08-16
# 2659   1977-01-01
# 2660   1939-07-28
# 2661   1982-01-01
# Name: birthDate, Length: 2662, dtype: datetime64[ns]

# %%
# Let's see what our dataframe looks like
df.head()
# Out:
#                uri  rank listUri  finalWorth                personName  \
# 0        elon-musk     1     rtb  245099.085                 Elon Musk
# 1  bernard-arnault     3     rtb  190894.988  Bernard Arnault & family
# 2       jeff-bezos     2     rtb  195904.053                Jeff Bezos
# 3       bill-gates     4     rtb  136434.782                Bill Gates
# 4    larry-ellison     5     rtb  127922.902             Larry Ellison
#
#           source          industries countryOfCitizenship  imageExists gender  \
# 0  Tesla, SpaceX        [Automotive]        United States         True      M
# 1           LVMH  [Fashion & Retail]               France         True      M
# 2         Amazon        [Technology]        United States         True      M
# 3      Microsoft        [Technology]        United States         True      M
# 4       software        [Technology]        United States         True      M
#
#    birthDate lastName  wealthList   estWorthPrev  familyList  \
# 0 1971-06-28     Musk       False  243802.398278       False
# 1 1949-03-05  Arnault       False  194919.714671       False
# 2 1964-01-12    Bezos       False  194758.378880       False
# 3 1955-10-28    Gates       False  137480.191240       False
# 4 1944-08-17  Ellison       False  134949.620303       False
#
#                                          squareImage  bioSuppress
# 0  https://specials-images.forbesimg.com/imageser...        False
# 1  //specials-images.forbesimg.com/imageserve/5dc...        False
# 2  https://specials-images.forbesimg.com/imageser...        False
# 3  https://specials-images.forbesimg.com/imageser...        False
# 4  //specials-images.forbesimg.com/imageserve/5e8...        False

# %%
# In this step i will calculate the age of every person we have 
# For that i'm importing datetime module so i can get today's date
from datetime import date, datetime
today = date.today()
today = np.datetime64(today)
print("Today is:", today)
# Out:
# Today is: 2021-12-18

# %%
# Creating function age calculator
def Age_cal(birthDate):
    birthDate = np.datetime64(birthDate)
    age = today - birthDate
    return age

# %%
# I create new column called Stagestep just as middle step to save my processed data in 
# I found there's a NAN values, so i used fillna method to replace them with today's date
df['Stagestep']=df['birthDate'].fillna(today)

# %%
# I apply the age calculator function to column
df['Stagestep'] = df['Stagestep'].apply(Age_cal)
# As u can see, i get the resualts as days unit
df['Stagestep']
# Out:
# 0      18436 days
# 1      26586 days
# 2      21160 days
# 3      24158 days
# 4      28247 days
#           ...
# 2657   33589 days
# 2658   17291 days
# 2659   16422 days
# 2660   30094 days
# 2661   14596 days
# Name: Stagestep, Length: 2662, dtype: timedelta64[ns]

# %%
# I apply the function from pandas timedelta64 and astype(int) methode to get days as integer number so ican perfrom calculation in the next step
df['Stagestep']=df['Stagestep'].apply(lambda x:np.timedelta64(x, 'D').astype(int))

# %%
# I create this function to return years from days by dividing on 356.25 days 
def get_years(days):
    return int(days / 365.25)

# %%
# I apply get_years function to 'Stagestep' to return years as intger numbers
df['Stagestep'] = df['Stagestep'].apply(get_years)
df['Stagestep']
# Out:
# 0       50
# 1       72
# 2       57
# 3       66
# 4       77
#         ..
# 2657    91
# 2658    47
# 2659    44
# 2660    82
# 2661    39
# Name: Stagestep, Length: 2662, dtype: int64

# %%
# I create function to return ages as string + "Years old"
def age_str(age):
    return str(age) + " Years old"
df["Age"] = df['Stagestep'].apply(age_str)
df["Age"]
# Out:
# 0       50 Years old
# 1       72 Years old
# 2       57 Years old
# 3       66 Years old
# 4       77 Years old
#             ...
# 2657    91 Years old
# 2658    47 Years old
# 2659    44 Years old
# 2660    82 Years old
# 2661    39 Years old
# Name: Age, Length: 2662, dtype: object

# %%
# Creating new dataframe with specfiques columns from our df + new column named Age
df_data = df[['rank', 'personName', 'finalWorth', 'Age', 'source', 'countryOfCitizenship']].copy()
df_data.head(10)
# Out:
#    rank                personName  finalWorth           Age  \
# 0     1                 Elon Musk  245099.085  50 Years old
# 1     3  Bernard Arnault & family  190894.988  72 Years old
# 2     2                Jeff Bezos  195904.053  57 Years old
# 3     4                Bill Gates  136434.782  66 Years old
# 4     5             Larry Ellison  127922.902  77 Years old
# 5     6                Larry Page  121500.649  48 Years old
# 6     7           Mark Zuckerberg  119421.209  37 Years old
# 7     8               Sergey Brin  117086.884  48 Years old
# 8     9            Warren Buffett  106848.201  91 Years old
# 9    10             Steve Ballmer  102514.694  65 Years old
#
#                source countryOfCitizenship
# 0       Tesla, SpaceX        United States
# 1                LVMH               France
# 2              Amazon        United States
# 3           Microsoft        United States
# 4            software        United States
# 5              Google        United States
# 6            Facebook        United States
# 7              Google        United States
# 8  Berkshire Hathaway        United States
# 9           Microsoft        United States

# %%
# Changing the names of columns
col_dict = {'rank':'Rank', 'personName':'Full Name', 'birthDate':'Birth Date', 'finalWorth':'Net Worth', 'source':'Source', 'countryOfCitizenship':'Country/Territory'}
# Creating a dict with new columns names to pass them to rename method
df_data.rename(columns=col_dict, inplace=True)

# %%
# Creating new column to calculate the percentage of each billionaire from global fourtune
df_data['Per from globalfourtune (%)'] = ((df_data['Net Worth'] / df_data['Net Worth'].sum())*100).round(decimals=2)
df_data
# Out:
#       Rank                 Full Name   Net Worth           Age  \
# 0        1                 Elon Musk  245099.085  50 Years old
# 1        3  Bernard Arnault & family  190894.988  72 Years old
# 2        2                Jeff Bezos  195904.053  57 Years old
# 3        4                Bill Gates  136434.782  66 Years old
# 4        5             Larry Ellison  127922.902  77 Years old
# ...    ...                       ...         ...           ...
# 2657  2655               Morris Kahn    1000.000  91 Years old
# 2658  2655         Mark Haoyong Yang    1000.000  47 Years old
# 2659  2655                   GT Dave    1000.000  44 Years old
# 2660  2655   Wilbur  'Ed' Bosarge Jr    1000.000  82 Years old
# 2661  2655               Hou Jianbin    1000.000  39 Years old
#
#                   Source Country/Territory  Per from globalfourtune (%)
# 0          Tesla, SpaceX     United States                         1.80
# 1                   LVMH            France                         1.40
# 2                 Amazon     United States                         1.44
# 3              Microsoft     United States                         1.00
# 4               software     United States                         0.94
# ...                  ...               ...                          ...
# 2657            software            Israel                         0.01
# 2658          e-commerce             China                         0.01
# 2659            kombucha     United States                         0.01
# 2660  high speed trading     United States                         0.01
# 2661           education             China                         0.01
#
# [2662 rows x 7 columns]

# %%
# I creat a top 10 billionaires + others billionaires so, i can perfome plotting 
# In this step i creat first dataframe to get top ten
df_billionaires = df_data[:10][['Full Name', 'Net Worth', 'Per from globalfourtune (%)']]
# In this one i creat other billionaires dataframe 
other_billionaires = df_data[10:][['Full Name', 'Net Worth', 'Per from globalfourtune (%)']]
other_billionaires = pd.DataFrame(data={'Full Name' : 'Other Billionaires',
                                        'Net Worth' : df_data[10:]['Net Worth'].sum(),
                                        'Per from globalfourtune (%)' : df_data[10:]['Per from globalfourtune (%)'].sum()}, 
                                  index=[0],
                                 )
# Here i concate the tow dataframes
top_billionaires = pd.concat([df_billionaires, other_billionaires]).reset_index(drop=True)
top_billionaires
# Out:
#                    Full Name     Net Worth  Per from globalfourtune (%)
# 0                  Elon Musk  2.450991e+05                         1.80
# 1   Bernard Arnault & family  1.908950e+05                         1.40
# 2                 Jeff Bezos  1.959041e+05                         1.44
# 3                 Bill Gates  1.364348e+05                         1.00
# 4              Larry Ellison  1.279229e+05                         0.94
# 5                 Larry Page  1.215006e+05                         0.89
# 6            Mark Zuckerberg  1.194212e+05                         0.88
# 7                Sergey Brin  1.170869e+05                         0.86
# 8             Warren Buffett  1.068482e+05                         0.79
# 9              Steve Ballmer  1.025147e+05                         0.75
# 10        Other Billionaires  1.214505e+07                        89.34

# %%
top_billionaires['Net Worth']
# Out:
# 0     2.450991e+05
# 1     1.908950e+05
# 2     1.959041e+05
# 3     1.364348e+05
# 4     1.279229e+05
# 5     1.215006e+05
# 6     1.194212e+05
# 7     1.170869e+05
# 8     1.068482e+05
# 9     1.025147e+05
# 10    1.214505e+07
# Name: Net Worth, dtype: float64

# %%
# I want to know how many country i have in my dataset so, i can get a preview of my worldwild plot 
# I used the unique() methode to count just the unique countrys and i used the method size so i can get the value 71 countries
print(str(df_data['Country/Territory'].unique().size) + " Countries")
# Out:
# 72 Countries

# %%
# We found that we have we have more than 13751782.162 Billions distributed through 71 countries
# So let's group by countries to found how much fortune we have for each country
grouped_fortune = df_data.groupby(['Country/Territory'], as_index = False).sum().sort_values('Net Worth', ascending=False)
# TOP 5 countries are US, CHINA, INDIA, Germany and RUSSIA
grouped_fortune = grouped_fortune[{'Country/Territory', 'Net Worth', 'Per from globalfourtune (%)'}].reset_index()
grouped_fortune.drop('index', axis=1, inplace=True)
grouped_fortune = grouped_fortune[['Country/Territory', 'Net Worth', 'Per from globalfourtune (%)']]
grouped_fortune
# Out:
#       Country/Territory    Net Worth  Per from globalfourtune (%)
# 0         United States  5037063.103                        36.93
# 1                 China  2274324.288                        16.73
# 2                 India   711215.264                         5.25
# 3               Germany   652402.147                         4.82
# 4                Russia   623642.995                         4.61
# ..                  ...          ...                          ...
# 67                Macao     2209.529                         0.02
# 68             Barbados     1701.000                         0.01
# 69  St. Kitts and Nevis     1645.886                         0.01
# 70             Tanzania     1567.238                         0.01
# 71                Nepal     1378.069                         0.01
#
# [72 rows x 3 columns]

# %%
# I did this step to count how many billionaires are in the our data and how many billions are there
billionaires = df_data['Full Name'].size
billiones = df_data['Net Worth'].sum()
print("We have {} billionaires with worth of {} Billiones".format(billionaires, round(billiones)))
# Out:
# We have 2662 billionaires with worth of 13608678 Billiones

# %%
##### Let's Start our data visualsation by plotting the grouped fortune for each country
# In this step i will create to new small dataframes the first is top 10 countries and the second is for the rest of countries
# the first dataframe
df_top = grouped_fortune[0:10] 
# Creating a place holders for two values 
net_worth = grouped_fortune[10:]['Net Worth'].sum().round()
pfg_data = grouped_fortune[10:]['Per from globalfourtune (%)'].sum().round()
# the second dataframe
df_others = pd.DataFrame(data={'Country/Territory': 'Other countries', 'Net Worth': net_worth, 'Per from globalfourtune (%)' : pfg_data}, index=[0])
# Concatenate the two dataframes
grouped_fortune = pd.concat([df_top, df_others]).reset_index(drop=True)
grouped_fortune = grouped_fortune[['Country/Territory', 'Net Worth', 'Per from globalfourtune (%)']] 
grouped_fortune
# Out:
#    Country/Territory    Net Worth  Per from globalfourtune (%)
# 0      United States  5037063.103                        36.93
# 1              China  2274324.288                        16.73
# 2              India   711215.264                         5.25
# 3            Germany   652402.147                         4.82
# 4             Russia   623642.995                         4.61
# 5             France   586937.939                         4.29
# 6          Hong Kong   417345.481                         3.05
# 7             Canada   233883.914                         1.71
# 8              Italy   209046.942                         1.57
# 9     United Kingdom   203605.090                         1.49
# 10   Other countries  2659211.000                        20.00

# %%
# In next step i ll rename the columns with using B and % as units to cleare that my numbers are in billions and percentage
grouped_fortune.rename(columns={'Net Worth':'Net Worth (Bi)'}, inplace=True)
top_countries = grouped_fortune
top_countries
# Out:
#    Country/Territory  Net Worth (Bi)  Per from globalfourtune (%)
# 0      United States     5037063.103                        36.93
# 1              China     2274324.288                        16.73
# 2              India      711215.264                         5.25
# 3            Germany      652402.147                         4.82
# 4             Russia      623642.995                         4.61
# 5             France      586937.939                         4.29
# 6          Hong Kong      417345.481                         3.05
# 7             Canada      233883.914                         1.71
# 8              Italy      209046.942                         1.57
# 9     United Kingdom      203605.090                         1.49
# 10   Other countries     2659211.000                        20.00

# %%
# Pie chart for top 10 countries 
# I build a list of zeros with the length of countries,so i can pass a value of 0.1 to explode last element "other countries"
explode = [0] * len(top_countries['Net Worth (Bi)'])
explode[-1] = 0.1
fig1, axe1 = plt.subplots(figsize=(10,10))
axe1.pie(x=top_countries['Net Worth (Bi)'], 
         labels=top_countries['Country/Territory'] ,
         explode = explode,
         autopct='%1.2f%%',
         pctdistance=0.9,
         wedgeprops={"edgecolor":"white", 'linewidth': 2, 'antialiased': True})
axe1.set_title("Fortune distribution across countries")
fig1.tight_layout()

# %%
# Let's Plot top 10 Billionaires using horizontal Bar chart builtin in matplotlib library to see how everyone of them shares
# Specifying the data we need
name = top_billionaires["Full Name"]
shares = top_billionaires["Net Worth"]

# Figure Size
fig2, axe2 = plt.subplots(figsize=(20, 7))
# Creating horizontal Bar Plot
axe2.barh(name, shares)
# Inverting the y axe to Showing top values
axe2.invert_yaxis() 
# Add annotation to bars
for i in axe2.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
# Setting tiltles
axe2.set_xlabel("Shares in billions")
axe2.set_ylabel("Full Name")
axe2.set_title("Shares of Billionaires from global fortune")
fig2.tight_layout()

# %% [markdown]
# # Start answring some questions

# %%
# In this step i want to answer a question
# Let's find out if there's any correlation between age and how much personal wealth?
# Remember that i store all ages as intgers in 'Stagestep'
df[['finalWorth', 'Stagestep']].corr()
# We found out that there's no correlation between age and wealth
# Out:
#             finalWorth  Stagestep
# finalWorth     1.00000    0.03852
# Stagestep      0.03852    1.00000

# %%
# We can go forward by plotting the data to see if there is any intersection between the tow lines
# Notice that i use Pandas build-in plot function
df[['finalWorth', 'Stagestep']].plot(xlim= (0, df['Stagestep'].max()))
# Out:
# <AxesSubplot:>

# %%
#Question: What's the industry makes more money? old saying that the petrol companies are the top, let's find out?
# So let's Group by industries to know which industry makes more money
df['industries'].head(20)
# I found that every element of 'industries' column is an list object
# So i need to make them str to performe a group by using pandas
# Out:
# 0                [Automotive]
# 1          [Fashion & Retail]
# 2                [Technology]
# 3                [Technology]
# 4                [Technology]
# 5                [Technology]
# 6                [Technology]
# 7                [Technology]
# 8     [Finance & Investments]
# 9                [Technology]
# 10         [Fashion & Retail]
# 11              [Diversified]
# 12              [Diversified]
# 13                  [Telecom]
# 14          [Food & Beverage]
# 15         [Fashion & Retail]
# 16    [Media & Entertainment]
# 17         [Fashion & Retail]
# 18         [Fashion & Retail]
# 19         [Fashion & Retail]
# Name: industries, dtype: object

# %%
# I will create a function to handle that 
# I found that the column contains some values not a list, so i control that using if statement
def list_to_str(lst):
    if type(lst) == list:
        mylist = ",".join(lst)
        return str(mylist)
    else:
        return "Unknown"

# %%
df['Industries'] = df['industries'].apply(list_to_str)
df_data['Industries'] = df['Industries']

# %%
groupby_Industries = df.groupby(['Industries'], as_index = False).sum().sort_values('finalWorth', ascending=False)
groupby_Industries[['Industries','finalWorth']].reset_index(drop=True)
# So we found out the answer for our question, is invest as much you can in Technology industry
# Out:
#                     Industries   finalWorth
# 0                   Technology  2693610.038
# 1             Fashion & Retail  1738825.958
# 2        Finance & Investments  1641406.697
# 3                Manufacturing  1167194.757
# 4              Food & Beverage   957996.010
# 5                  Diversified   911874.130
# 6                   Healthcare   787317.093
# 7                  Real Estate   737823.429
# 8                   Automotive   678929.203
# 9                       Energy   483125.931
# 10       Media & Entertainment   459426.618
# 11             Metals & Mining   440395.482
# 12                     Telecom   208164.762
# 13                     Service   198187.740
# 14                   Logistics   156404.984
# 15  Construction & Engineering   125076.248
# 16          Gambling & Casinos   105717.130
# 17                      Sports    96221.643
# 18                     Unknown    20980.402

# %%
df_data
# Out:
#       Rank                 Full Name   Net Worth           Age  \
# 0        1                 Elon Musk  245099.085  50 Years old
# 1        3  Bernard Arnault & family  190894.988  72 Years old
# 2        2                Jeff Bezos  195904.053  57 Years old
# 3        4                Bill Gates  136434.782  66 Years old
# 4        5             Larry Ellison  127922.902  77 Years old
# ...    ...                       ...         ...           ...
# 2657  2655               Morris Kahn    1000.000  91 Years old
# 2658  2655         Mark Haoyong Yang    1000.000  47 Years old
# 2659  2655                   GT Dave    1000.000  44 Years old
# 2660  2655   Wilbur  'Ed' Bosarge Jr    1000.000  82 Years old
# 2661  2655               Hou Jianbin    1000.000  39 Years old
#
#                   Source Country/Territory  Per from globalfourtune (%)  \
# 0          Tesla, SpaceX     United States                         1.80
# 1                   LVMH            France                         1.40
# 2                 Amazon     United States                         1.44
# 3              Microsoft     United States                         1.00
# 4               software     United States                         0.94
# ...                  ...               ...                          ...
# 2657            software            Israel                         0.01
# 2658          e-commerce             China                         0.01
# 2659            kombucha     United States                         0.01
# 2660  high speed trading     United States                         0.01
# 2661           education             China                         0.01
#
#                  Industries
# 0                Automotive
# 1          Fashion & Retail
# 2                Technology
# 3                Technology
# 4                Technology
# ...                     ...
# 2657             Technology
# 2658             Technology
# 2659        Food & Beverage
# 2660  Finance & Investments
# 2661                Service
#
# [2662 rows x 8 columns]

# %%
# Next to do is writing df_data to CSV file, so i can build dashboard using Tableau Software
df_data.to_csv('data.csv', index=False)
